# %%
#import the nitty gritty
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# read the csv file and store into a variable
data = pd.read_csv("data.csv",error_bad_lines=False)
# we can see that line 52431 and 131201 are bad lines, we're skipping them
# Out:
# b'Skipping line 52431: expected 8 fields, saw 9\n'
# b'Skipping line 131201: expected 8 fields, saw 9\n'

# %%
# lets see the current description of the data
data.describe(include='all')
# Out:
#        loan_status      loan_amnt       int_rate   grade emp_length  \
# count       148035  148035.000000  148035.000000  148035     148035
# unique          10            NaN            NaN       5          3
# top        Current            NaN            NaN       A         >5
# freq        142255            NaN            NaN   44346      77659
# mean           NaN   15976.937380      12.831402     NaN        NaN
# std            NaN   10117.463288       5.002907     NaN        NaN
# min            NaN    1000.000000       6.000000     NaN        NaN
# 25%            NaN    8000.000000       8.460000     NaN        NaN
# 50%            NaN   14000.000000      11.800000     NaN        NaN
# 75%            NaN   21525.000000      16.140000     NaN        NaN
# max            NaN   40000.000000      27.270000     NaN        NaN
#
#        home_ownership annual_inc    term
# count          148035     148035  148035
# unique              6      10872       2
# top          MORTGAGE      60000      36
# freq            73126       5884  101901
# mean              NaN        NaN     NaN
# std               NaN        NaN     NaN
# min               NaN        NaN     NaN
# 25%               NaN        NaN     NaN
# 50%               NaN        NaN     NaN
# 75%               NaN        NaN     NaN
# max               NaN        NaN     NaN

# %%
# OK, so nothing seems worong atm, lets check for empty value
data.isnull()
# Out:
#         loan_status  loan_amnt  int_rate  grade  emp_length  home_ownership  \
# 0             False      False     False  False       False           False
# 1             False      False     False  False       False           False
# 2             False      False     False  False       False           False
# 3             False      False     False  False       False           False
# 4             False      False     False  False       False           False
# ...             ...        ...       ...    ...         ...             ...
# 149992        False      False     False  False       False           False
# 149993        False      False     False  False        True           False
# 149994        False      False     False  False       False           False
# 149995        False      False     False  False       False           False
# 149996        False      False     False  False       False           False
#
#         annual_inc   term
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...            ...    ...
# 149992       False  False
# 149993       False  False
# 149994       False  False
# 149995       False  False
# 149996       False  False
#
# [149997 rows x 8 columns]

# %%
# we can see that there are a rows that contain null data, lets count how many
data.isnull().sum()
# Out:
# loan_status           0
# loan_amnt             0
# int_rate              0
# grade                 0
# emp_length        13668
# home_ownership        1
# annual_inc            0
# term                  0
# dtype: int64

# %%
# Since emp_length and home_ownership are categorical data, we can replace each empty row with it's mode
data['emp_length'].fillna(data['emp_length'].mode()[0],inplace=True)
data['home_ownership'].fillna(data['home_ownership'].mode()[0],inplace=True)

# %%
# Lets look at the data
data.isnull().sum()
# No more empty rows, awesome!
# Out:
# loan_status       0
# loan_amnt         0
# int_rate          0
# grade             0
# emp_length        0
# home_ownership    0
# annual_inc        0
# term              0
# dtype: int64

# %%
# Now, we got no missing data, lets try seeing the data as a whole
data.describe()
# Out:
#            loan_amnt       int_rate
# count  149997.000000  149997.000000
# mean    16020.131903      12.908371
# std     10138.276997       5.127491
# min      1000.000000       6.000000
# 25%      8000.000000       8.460000
# 50%     14000.000000      11.800000
# 75%     22000.000000      16.140000
# max     40000.000000      30.990000

# %%
# notice that there are several columns that can be replaced with integers only e.g. emp_length and term, lets do that
def parse_term(row):
    try:
        return row.split(" ")[1]
    except:
        print("term => ",row)


def parse_emp_length(row):
    try:
        row_length = len(row.split(" "))
        if(row_length == 2):
            return row.split(" ")[0]
        elif row_length == 3:
            return "".join(row.split(" ")[0:2:1])
    except:
        print("emp_length =>",row)
    

data['emp_length'] = data.apply(lambda row: parse_emp_length(row.emp_length), axis=1)
data['term'] = data.apply(lambda row: parse_term(row.term), axis=1)
# lets see the result
data.head(10)
# Out:
#   loan_status  loan_amnt  int_rate grade emp_length home_ownership annual_inc  \
# 0     Current       2500     13.56     C        10+           RENT      55000
# 1     Current      30000     18.94     D        10+       MORTGAGE      90000
# 2     Current       5000     17.97     D          6       MORTGAGE      59280
# 3     Current       4000     18.94     D        10+       MORTGAGE      92000
# 4     Current      30000     16.14     C        10+       MORTGAGE      57250
# 5     Current       5550     15.02     C        10+       MORTGAGE     152500
# 6     Current       2000     17.97     D          4           RENT      51000
# 7     Current       6000     13.56     C        10+           RENT      65000
# 8     Current       5000     17.97     D        10+       MORTGAGE      53580
# 9     Current       6000     14.47     C         <1            OWN     300000
#
#   term
# 0   36
# 1   60
# 2   36
# 3   36
# 4   60
# 5   36
# 6   36
# 7   36
# 8   36
# 9   36

# %%
# we have solved the term column, now lets take a look at emp_length
print(dict(data['emp_length'].value_counts()))
# we can see that there are irrelevant data if the count is less than 400, so we are dropping them
data = data[data.groupby('emp_length').emp_length.transform('count')>400]
data['emp_length'].value_counts()
# Out:
# {'10+': 58735, '<1': 18326, '2': 12574, '3': 11701, '1': 10395, '5': 8984, '4': 8719, '6': 6288, '7': 5065, '8': 4742, '9': 3226, '': 332, 'Business': 30, 'Human': 13, 'Client': 12, 'Product': 11, 'IT': 9, 'Customer': 9, 'Talent': 9, 'Information': 8, 'Digital': 7, 'Program': 6, 'Data': 6, 'North': 5, 'Professional': 5, 'Technical': 5, 'Global': 5, 'Public': 5, 'Technology': 5, 'Consumer': 4, 'Marketing': 4, 'Project': 4, 'Field': 4, 'Employee': 4, 'Financial': 4, 'Sales': 4, 'National': 4, 'Clinical': 4, 'Compliance': 4, 'Brand': 4, 'Regulatory': 3, 'Legal': 3, 'Network': 3, 'Commercial': 3, 'Branch': 3, 'Patient': 3, 'Media': 3, 'Application': 3, 'Retail': 3, 'Operations': 3, 'Process': 3, 'Internal': 2, 'Quality': 2, 'Organizational': 2, 'Sustainability': 2, 'Corporate': 2, 'Clinic': 2, 'Shared': 2, 'Franchise': 2, 'Senior': 2, 'Visitor': 2, 'assistant': 2, 'Instructional': 2, 'Security': 2, 'Specialty': 2, 'Registered': 2, 'Campus': 2, 'medical': 2, 'Creative': 2, 'Team': 2, 'Cloud': 2, 'Market': 2, 'Student': 2, 'Research': 2, 'Revenue': 2, 'Claims': 2, 'Speech': 2, 'Manager': 2, 'HR': 2, 'Staff': 2, 'Engineering': 2, 'Supply': 2, 'Logistics': 2, 'Head': 2, 'Leadership': 2, 'Strategic': 2, 'Systems': 2, 'Solutions': 2, 'IS': 2, 'Enterprise': 2, 'vice': 1, 'consultant': 1, 'Contract': 1, 'ATU': 1, 'elementary': 1, 'HSIS': 1, 'External': 1, 'property': 1, 'Council': 1, 'equipment': 1, 'HR/Administrative': 1, 'Advisor': 1, 'Advisory': 1, 'SOCIAL': 1, 'TechnicalSpecialist': 1, 'HUMAN': 1, 'Affiliate': 1, 'IP': 1, 'Informatics': 1, 'supervisor': 1, 'Route': 1, 'admin': 1, '&Data': 1, 'Warehouse': 1, 'Partnership': 1, 'International': 1, 'Gym': 1, 'Early': 1, 'Food': 1, 'Street': 1, 'foodand': 1, 'Mill': 1, 'diesal': 1, 'Bakery': 1, 'Rx': 1, 'Institutional': 1, 'Mid': 1, 'Bus': 1, 'MoldRestoration': 1, 'Portfolio': 1, 'medicalassistant': 1, 'Showing': 1, 'Housekeeping': 1, 'Corporare': 1, 'Outcomes': 1, 'Banking': 1, 'Facilities': 1, 'Volunteer': 1, 'Cal': 1, 'personnel': 1, 'NonInvasive': 1, 'Counseling': 1, 'first': 1, 'Finance/Admin/Purchasing': 1, 'Ad': 1, 'Applications': 1, 'Participant': 1, 'Government': 1, 'Author': 1, 'Surgical': 1, 'Kazakh': 1, 'Military': 1, 'Engagement': 1, 'Experiential': 1, 'Charitable': 1, 'Philadelphia': 1, 'compensation': 1, 'Cost': 1, 'Service': 1, 'auto': 1, 'Construction': 1, 'business': 1, 'customer': 1, 'Associate': 1, 'independent': 1, 'Radiology': 1, 'Logisitics': 1, 'Conference': 1, 'Emergency': 1, 'Drug': 1, 'Sports': 1, 'Performance': 1, 'RESOURCE': 1, 'Single': 1, 'Trainer': 1, 'C&E': 1, 'Counselor': 1, 'Operational': 1, 'Fraud': 1, 'of': 1, 'Advertising': 1, 'Braille': 1, 'Dispute': 1, 'USA': 1, 'regional': 1, 'associate': 1, 'Sourcing': 1, 'support': 1, 'Wealth': 1, 'finance': 1, 'Collections': 1, 'Procurement': 1, 'Demand': 1, 'Acquisition': 1, 'Chemical': 1, 'Records': 1, 'Finance-': 1, 'FRONT': 1, 'Lead': 1, 'Investment': 1, 'COA': 1, 'AV': 1, 'MEMBER': 1, 'facilities': 1, 'foreman': 1, 'Vulnerability': 1, 'Package': 1, 'Dept': 1, 'Btrand': 1, 'Biomedical': 1, 'Compute': 1, 'Central': 1, 'Northeast': 1, 'risk': 1, 'insurance': 1, 'VP': 1, 'Special': 1, 'Distribution': 1, 'fabricator': 1, 'Sr.': 1, '2nd': 1, 'Search': 1, 'Proposals': 1, 'Finance': 1, 'Account': 1, 'speech-language': 1, 'Interactive': 1, 'Development': 1, 'Automotive': 1, 'Land': 1, 'Ocular': 1, 'Energy': 1, 'surgery': 1, 'ACCOUNTING': 1, 'Workforce': 1, 'First': 1, 'Communications': 1, 'Donor': 1, 'Licensed': 1, 'FAMILY': 1, 'prep': 1, 'TPA': 1, 'Database': 1, 'Assistant': 1, 'Utility': 1, 'Physical': 1, 'General': 1, 'FAA': 1, 'Statistical': 1, 'Practice': 1, 'Online': 1, 'Parts': 1, 'Resource': 1, 'INTL': 1, 'lead': 1, 'Decision': 1, 'Oregon': 1, 'Environmental': 1, 'User': 1, 'Machinery': 1, 'special': 1, 'ophthalmic': 1, 'Cognitive': 1, 'HEALTH': 1, 'FP&A': 1, 'Oracle': 1, 'RIGHTS': 1, 'Purchasing': 1, 'Expense': 1, 'Windows': 1, 'Health': 1, 'Payee': 1, 'Bugdet': 1, 'Legal/Executive': 1, 'dept': 1, 'Self': 1, ...
# 10+    58735
# <1     18326
# 2      12574
# 3      11701
# 1      10395
# 5       8984
# 4       8719
# 6       6288
# 7       5065
# 8       4742
# 9       3226
# Name: emp_length, dtype: int64

# %%
data['emp_length'].value_counts()
# Out:
# 10+    58735
# <1     18326
# 2      12574
# 3      11701
# 1      10395
# 5       8984
# 4       8719
# 6       6288
# 7       5065
# 8       4742
# 9       3226
# Name: emp_length, dtype: int64

# %%
# # lets take a look at the processed data data, notice the column "emp_length", still has a lot of unstandardized data like "10+" and "<1"
# # lets clean them up

# 1. make a function that accepts a row, and return a cleaned - more standardized data
# here we categorize the data into <5, 5, and >5, way more easier to read!
def clean_emp_length(row):
    if row == "10+":
        return ">5"
    elif row == "<1":
        return "<5"
    elif int(row) == 5:
        return "5"
    elif int(row) < 5:
        return "<5"
    elif int(row) > 5:
        return ">5"

# # 2. Lets apply the function to the data
data['emp_length'] = data.apply(lambda row: clean_emp_length(row.emp_length), axis=1)
# # lets see the result
data['emp_length'].value_counts()
# Out:
# >5    78056
# <5    61715
# 5      8984
# Name: emp_length, dtype: int64

# %%
# So now lets take  a look at our data
data.head()
# Out:
#   loan_status  loan_amnt  int_rate grade emp_length home_ownership annual_inc  \
# 0     Current       2500     13.56     C         >5           RENT      55000
# 1     Current      30000     18.94     D         >5       MORTGAGE      90000
# 2     Current       5000     17.97     D         >5       MORTGAGE      59280
# 3     Current       4000     18.94     D         >5       MORTGAGE      92000
# 4     Current      30000     16.14     C         >5       MORTGAGE      57250
#
#   term
# 0   36
# 1   60
# 2   36
# 3   36
# 4   60

# %%
TO_NUMERIC = ['loan_amnt','int_rate','annual_inc','term']
for col in TO_NUMERIC:
    pd.to_numeric(data[col])

# %%
data = data.dropna()
data.describe()
# Out:
#            loan_amnt       int_rate
# count  148755.000000  148755.000000
# mean    15979.367920      12.913401
# std     10117.504364       5.127777
# min      1000.000000       6.000000
# 25%      8000.000000       8.460000
# 50%     14000.000000      11.800000
# 75%     21600.000000      16.140000
# max     40000.000000      30.990000

# %%
data.boxplot(column =['int_rate'], grid = False) 
# we have a lot of outliers judging from the boxplot
# Out:
# <AxesSubplot:>

# %%
plt.hist(data.int_rate)
plt.show()
# we can see that there are outliers

# %%
# remove the outlier, keep the ones that Z score between 3 of std deviation
data = data[np.abs(data.int_rate-data.int_rate.mean()) <= (3*data.int_rate.std())]

# %%
# check the current histogram, seems good!
plt.hist(data.int_rate)
plt.show()

# %%
data.boxplot(column =['int_rate'], grid = False) 
# All the outliers are gone now!
# Out:
# <AxesSubplot:>

# %%
data.describe(include='all')
# data['term'].count_values
# Out:
#        loan_status      loan_amnt       int_rate   grade emp_length  \
# count       148035  148035.000000  148035.000000  148035     148035
# unique          10            NaN            NaN       5          3
# top        Current            NaN            NaN       A         >5
# freq        142255            NaN            NaN   44346      77659
# mean           NaN   15976.937380      12.831402     NaN        NaN
# std            NaN   10117.463288       5.002907     NaN        NaN
# min            NaN    1000.000000       6.000000     NaN        NaN
# 25%            NaN    8000.000000       8.460000     NaN        NaN
# 50%            NaN   14000.000000      11.800000     NaN        NaN
# 75%            NaN   21525.000000      16.140000     NaN        NaN
# max            NaN   40000.000000      27.270000     NaN        NaN
#
#        home_ownership annual_inc    term
# count          148035     148035  148035
# unique              6      10872       2
# top          MORTGAGE      60000      36
# freq            73126       5884  101901
# mean              NaN        NaN     NaN
# std               NaN        NaN     NaN
# min               NaN        NaN     NaN
# 25%               NaN        NaN     NaN
# 50%               NaN        NaN     NaN
# 75%               NaN        NaN     NaN
# max               NaN        NaN     NaN

# %%
# saving
# data.to_csv('cleaned_data.csv',index=None, header=True)
